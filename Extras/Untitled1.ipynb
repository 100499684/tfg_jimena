# %%
import time

# Aquí puedes poner el código de monitoreo
print("📊 MONITOREO REMOTO")
print("="*40)

# Pregunta cuánto tiempo llevas
minutos = input("¿Cuántos minutos llevas de entrenamiento? (aprox): ")
epocas = input("¿Cuántas épocas se han completado?: ")

try:
    mins = float(minutos)
    eps = float(epocas)
    
    if eps > 0:
        tiempo_por_epoca = mins / eps
        print(f"\n⏱️  Tiempo por época: {tiempo_por_epoca:.1f} minutos")
        
        if tiempo_por_epoca < 30:
            print("✅ Rápido - GPU funcionando bien")
        elif tiempo_por_epoca < 60:
            print("⚠️ Normal - Aceptable")
        else:
            print("🐢 Lento - Revisar configuración")
            
        print(f"📈 Para 20 épocas total: {tiempo_por_epoca*10:.1f} minutos ({tiempo_por_epoca*20/60:.1f} horas)")
except:
    print("Por favor, introduce números válidos")
# Out:
# 📊 MONITOREO REMOTO
# ...
# ¿Cuántos minutos llevas de entrenamiento? (aprox):  218
# ¿Cuántas épocas se han completado?:  5
# ⏱️  Tiempo por época: 43.6 minutos
# ⚠️ Normal - Aceptable
# 📈 Para 10 épocas total: 436.0 minutos (7.3 horas)

# %%
print("GPUs disponibles:", tf.config.list_physical_devices('GPU'))
# Out:
# GPUs disponibles: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from tensorflow.keras.applications import EfficientNetB3

model = EfficientNetB3(
    weights=None
)

print(len(model.layers))
# Out:
# 387

# %%
from tensorflow.keras.applications import MobileNetV2

model = MobileNetV2(
    weights=None
)

print(len(model.layers))
# Out:
# 156

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

from tensorflow.keras.applications import VGG16

model = VGG16(weights=None, include_top=True)
model.summary()
# Out:
# 2026-05-30 13:40:18.653110: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.50MiB (rounded to 4718592)requested by op StatelessRandomUniformV2
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2026-05-30 13:40:18.653174: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1049] BFCAllocator dump for GPU_0_bfc
# 2026-05-30 13:40:18.653182: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (256): 	Total Chunks: 448, Chunks in use: 448. 112.0KiB allocated for chunks. 112.0KiB in use in bin. 39.1KiB client-requested in use in bin.
# ...
